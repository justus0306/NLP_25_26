# %% [markdown]
# # Lab 1 - Project Kickoff Notes
#
# ## Team Members
# - Justus Jochum
# - Hikmet Acig
# - Sunny Wicklein
#
# ## Topic & Dataset
# - Chosen topic: **Tweet Topics**
# - Dataset: [cardiffnlp/tweet_topic_multi](https://huggingface.co/datasets/cardiffnlp/tweet_topic_multi) from Hugging Face
# - Initial action items: download the dataset, explore topic balance, and ensure everyone can load it locally.
#
# ## Collaboration Setup
# - Version control: GitLab repository at https://gitlab.lrz.de/000000003B9C56AA/grundlagen-des-nlp-ws25_26
# - Shared tooling: VS Code with Jupyter notebooks (local execution environment for all labs)
# - Communication channels: Discord for async updates, WhatsApp for quick check-ins.
#
# ## Kickoff Checklist
# - Complete the AI survey and try out Penelope as required in Lab 1 instructions.
# - Confirm the 3-person group, document the topic choice, and align on the dataset.
# - Finish the technical setup (Git, environment, notebook tooling, communication).
