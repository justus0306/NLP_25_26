# %%
# Install necessary packages
# %pip install pandas 
# %pip install nltk
# %pip install spacy
# %pip install pyarrow
# %pip install datasets

import pandas as pd

# Load the dataset
df = pd.read_parquet('../Data/tweet_topics_all.parquet', engine='pyarrow')

# Filter the dataset to text only (no numbers)
def filter_to_text_only(dataframe, text_col='text', label_col='label_name'):
    df_filtered = dataframe[[text_col, label_col]].copy()
    df_filtered[text_col] = df_filtered[text_col].str.replace(r'\d+', '', regex=True)
    
    if isinstance(df_filtered[label_col].iloc[0], list):
        pass
    else:
        df_filtered[label_col] = df_filtered[label_col].astype(str)
    
    df_filtered[text_col] = df_filtered[text_col].str.replace(r'\s+', ' ', regex=True).str.strip()
    
    return df_filtered

df_text_only = filter_to_text_only(df)

print("\n✓ Dataset successfully loaded and filtered to text only")
# Out:
# Requirement already satisfied: pandas in c:\users\jochu\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jochu\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jochu\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jochu\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jochu\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jochu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nltk in c:\users\jochu\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\jochu\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\jochu\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jochu\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\jochu\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\jochu\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spacy in c:\users\jochu\anaconda3\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\jochu\anaconda3\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\jochu\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jochu\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\jochu\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\jochu\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jochu\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jochu\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jochu\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jochu\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\jochu\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\jochu\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\jochu\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jochu\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\jochu\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\jochu\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.1)
# Requirement already satisfied: wrapt in c:\users\jochu\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\jochu\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jochu\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyarrow in c:\users\jochu\anaconda3\lib\site-packages (21.0.0)
# Note: you may need to restart the kernel to use updated packages.
#
# ✓ Dataset successfully loaded and filtered to text only

# %%
# Download required NLTK data
import nltk
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('punkt_tab', quiet=True)

# Load SpaCy model
import spacy
try:
    nlp = spacy.load('en_core_web_sm')
    print("✓ SpaCy model loaded successfully")
except:
    print("Installing SpaCy model...")
    import os
    os.system('python -m spacy download en_core_web_sm')
    nlp = spacy.load('en_core_web_sm')
    print("✓ SpaCy model loaded successfully")

def is_latin_alphabet(word):
    """
    Check if a word contains only Latin alphabet characters.
    Filters out words with Cyrillic, Arabic, Chinese, etc.
    Keeps hashtag texts and modern social media terms.
    """
    if not word:
        return False
    return all(ord('a') <= ord(c.lower()) <= ord('z') for c in word)

def preprocess_tweet(text):
    """
    Topic-optimized preprocessing for tweet classification.
    Preserves topic-relevant information while removing noise.
    Removes special characters, emojis, and non-Latin script words.
    """
    if not isinstance(text, str):
        return ""
    
    # Step 1: Remove RT (retweet indicator)
    text = text.replace('RT ', ' ').replace('rt ', ' ')
    
    # Step 2: Remove URLs and placeholders
    text = text.replace('{{URL}}', ' ')
    text = text.replace('{{USERNAME}}', ' ')
    for protocol in ['https://', 'http://', 'www.']:
        if protocol in text:
            parts = text.split(protocol)
            text = parts[0] + ' ' + ' '.join([' '.join(p.split()[1:]) if p.split() else '' for p in parts[1:]])
    
    # Step 3: Remove mentions
    words_list = text.split()
    words_list = [w for w in words_list if not (w.startswith('{@') or w.startswith('@'))]
    text = ' '.join(words_list)
    
    # Step 4: Extract hashtag text (#Gaming → gaming)
    words_list = text.split()
    words_list = [w[1:] if w.startswith('#') else w for w in words_list]
    text = ' '.join(words_list)
    
    # Step 5: Normalize whitespace and lowercase
    text = ' '.join(text.split())
    text = text.lower()
    
    # Step 6: Tokenize with SpaCy
    doc = nlp(text)
    
    # Define topic-relevant words to KEEP (even if they're stopwords)
    keep_words = {'game', 'music', 'news', 'sport', 'film', 'video', 'watch', 'play'}
    
    # Step 7: Filter and lemmatize tokens
    processed_tokens = []
    for token in doc:
        # Skip punctuation
        if token.is_punct:
            continue
        
        # Skip if not alphabetic (removes special characters, emojis, numbers)
        if not token.is_alpha:
            continue
        
        # Skip tokens shorter than 2 characters
        if len(token.text) < 2:
            continue
        
        # Keep topic-relevant words even if they're stopwords
        if token.text in keep_words or token.lemma_ in keep_words:
            processed_tokens.append(token.lemma_)
            continue
        
        # Remove stopwords (using SpaCy's stopword detection)
        if token.is_stop:
            continue
        
        # Check if word uses Latin alphabet (filters out Cyrillic, Arabic, Chinese, etc.)
        if not is_latin_alphabet(token.text):
            continue
        
        # Use lemmatized form
        processed_tokens.append(token.lemma_)
    
    return ' '.join(processed_tokens)

# Create a copy of the original dataframe
df_preprocessed = df_text_only.copy()

# Apply preprocessing
df_preprocessed['text'] = df_preprocessed['text'].apply(preprocess_tweet)

print("\n✓ Preprocessing complete!")
print(f"✓ Processed {len(df_preprocessed)} tweets")
print(f"✓ Original 'df_text_only' unchanged | Processed data in 'df_preprocessed'")
# Out:
# ✓ SpaCy model loaded successfully
#
# ✓ Preprocessing complete!
# ✓ Processed 6090 tweets
# ✓ Original 'df_text_only' unchanged | Processed data in 'df_preprocessed'
